# %%
attention_components = [
    "Tokenizer",
    "Embeddings",
    "Self-Attention",
    "Cross-Attention",
    "Image Features"
]

for component in attention_components:
    print(component)
# Out:
# Tokenizer
# Embeddings
# Self-Attention
# Cross-Attention
# Image Features

# %% [markdown]
# Prompt
# ↓
# Tokenizer
# ↓
# Embeddings
# ↓
# Cross-Attention
# ↓
# UNet
# ↓
# Generated Image

# %%
workflow = {
    "Prompt": "Input Text",
    "Tokenizer": "Token Creation",
    "Embeddings": "Semantic Representation",
    "Cross-Attention": "Text-Image Alignment",
    "Generation": "Image Output"
}

for key, value in workflow.items():
    print(f"{key}: {value}")
# Out:
# Prompt: Input Text
# Tokenizer: Token Creation
# Embeddings: Semantic Representation
# Cross-Attention: Text-Image Alignment
# Generation: Image Output
