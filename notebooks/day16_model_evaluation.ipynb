# %%
evaluation_metrics = [
    "Prompt Alignment",
    "Visual Quality",
    "Style Consistency",
    "Artifact Reduction"
]

for metric in evaluation_metrics:
    print(metric)
# Out:
# Prompt Alignment
# Visual Quality
# Style Consistency
# Artifact Reduction

# %%
comparison_results = {
    "Prompt Alignment": 9,
    "Visual Quality": 8,
    "Style Consistency": 9,
    "Artifact Reduction": 8
}

for metric, score in comparison_results.items():
    print(metric, ":", score)
# Out:
# Prompt Alignment : 9
# Visual Quality : 8
# Style Consistency : 9
# Artifact Reduction : 8

# %%
import pandas as pd

data = {
    "Metric": [
        "Prompt Alignment",
        "Visual Quality",
        "Style Consistency",
        "Artifact Reduction"
    ],
    "Score": [9, 8, 9, 8]
}

df = pd.DataFrame(data)

print(df)
# Out:
#                Metric  Score
# 0    Prompt Alignment      9
# 1      Visual Quality      8
# 2   Style Consistency      9
# 3  Artifact Reduction      8
