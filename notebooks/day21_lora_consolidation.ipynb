# %%
workflow = [
    "Dataset",
    "Tokenization",
    "Latent Encoding",
    "LoRA Adapters",
    "Training",
    "Inference",
    "Evaluation"
]

for step in workflow:
    print(step)
# Out:
# Dataset
# Tokenization
# Latent Encoding
# LoRA Adapters
# Training
# Inference
# Evaluation

# %%
completed_modules = [
    "Dataset Preparation",
    "Training Setup",
    "Checkpoint Workflow",
    "Inference Workflow",
    "Evaluation Workflow"
]

for module in completed_modules:
    print(module)
# Out:
# Dataset Preparation
# Training Setup
# Checkpoint Workflow
# Inference Workflow
# Evaluation Workflow
