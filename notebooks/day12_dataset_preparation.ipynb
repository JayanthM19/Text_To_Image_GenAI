# %%
dataset_info = {
    "recommended_images": 20,
    "image_resolution": "512x512",
    "caption_required": True
}

print(dataset_info)
# Out:
# {'recommended_images': 20, 'image_resolution': '512x512', 'caption_required': True}

# %%
example_captions = [
    "A realistic orange cat sitting near a window",
    "A futuristic cyberpunk city with neon lights",
    "An anime girl standing in a flower garden"
]

for caption in example_captions:
    print(caption)
# Out:
# A realistic orange cat sitting near a window
# A futuristic cyberpunk city with neon lights
# An anime girl standing in a flower garden
