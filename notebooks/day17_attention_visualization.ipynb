# %%
tokens = [
    "red",
    "car",
    "blue",
    "house"
]

for token in tokens:
    print(token)
# Out:
# red
# car
# blue
# house

# %%
attention_pairs = {
    "red": "car",
    "blue": "house"
}

for token, target in attention_pairs.items():
    print(f"{token} → {target}")
# Out:
# red → car
# blue → house

# %%
workflow = [
    "Prompt",
    "Tokenization",
    "Embeddings",
    "Cross-Attention",
    "Image Features",
    "Generation"
]

for step in workflow:
    print(step)
# Out:
# Prompt
# Tokenization
# Embeddings
# Cross-Attention
# Image Features
# Generation
