# %%
base_model = "Stable Diffusion v1.5"

lora_adapter = "custom_style_lora"

print("Base Model:", base_model)

print("Loaded Adapter:", lora_adapter)
# Out:
# Base Model: Stable Diffusion v1.5
# Loaded Adapter: custom_style_lora

# %%
workflow = [
    "Load Base Model",
    "Load LoRA Adapter",
    "Merge Weights",
    "Generate Images",
    "Evaluate Outputs"
]

for step in workflow:
    print(step)
# Out:
# Load Base Model
# Load LoRA Adapter
# Merge Weights
# Generate Images
# Evaluate Outputs

# %%
prompts = [
    "A futuristic city",
    "A fantasy castle",
    "A cyberpunk street"
]

for prompt in prompts:
    print("Generating:", prompt)
# Out:
# Generating: A futuristic city
# Generating: A fantasy castle
# Generating: A cyberpunk street
