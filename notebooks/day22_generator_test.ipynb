# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

print(sys.path[-1])
# Out:
# c:\Users\JAYANTH\Documents\ElevanceSkills\Text_to_Img\stable-diffusion-project

# %%
import torch

from task6_cgan.generator import Generator

# %%
generator = Generator()

# %%
noise = torch.randn(
    8,
    100
)

labels = torch.randint(
    0,
    10,
    (8,)
)

# %%
fake_images = generator(
    noise,
    labels
)

print(fake_images.shape)
# Out:
# torch.Size([8, 1, 28, 28])
