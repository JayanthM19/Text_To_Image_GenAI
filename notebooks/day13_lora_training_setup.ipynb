# %%
training_config = {
    "learning_rate": 1e-4,
    "batch_size": 1,
    "epochs": 10,
    "resolution": 512,
    "lora_rank": 4,
    "lora_alpha": 16
}

print(training_config)
# Out:
# {'learning_rate': 0.0001, 'batch_size': 1, 'epochs': 10, 'resolution': 512, 'lora_rank': 4, 'lora_alpha': 16}

# %%
dataset_workflow = [
    "Load Images",
    "Load Captions",
    "Tokenization",
    "Latent Encoding",
    "LoRA Adapter Training",
    "Checkpoint Saving"
]

for step in dataset_workflow:
    print(step)
# Out:
# Load Images
# Load Captions
# Tokenization
# Latent Encoding
# LoRA Adapter Training
# Checkpoint Saving

# %%
total_steps = 10 * 20

print("Estimated Training Steps:", total_steps)
# Out:
# Estimated Training Steps: 200

# %%
parameters = {
    "rank": 4,
    "alpha": 16
}

for key, value in parameters.items():
    print(key, value)
# Out:
# rank 4
# alpha 16
